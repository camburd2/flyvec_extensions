# %%
from datasets import load_dataset
from tqdm import tqdm
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
dataset = load_dataset("openwebtext", trust_remote_code=True) # 45 mins first time, after that 1.5 mins
# Out:
# Loading dataset shards:   0%|          | 0/80 [00:00<?, ?it/s]

# %%
import json

# Load vocab
flyvec_embeddings_path = 'simple-flyvec-embeddings.json'
with open(flyvec_embeddings_path, 'r') as file:
    embeddings = json.load(file)


vocab = {word: idx for idx, word in enumerate(embeddings.keys())}

# %%
from encoder import Encoder
from flyvec_model import FlyvecModel
from collections import Counter
import numpy as np
import utils

encoder = Encoder(vocab=vocab)


# Create model
model = FlyvecModel(
    K_size=400,            # Number of neurons
    vocab_size=len(vocab),  # Size of vocab
    k=1,                    # Update top-k neurons
    lr=.2,                  # Learning rate
    norm_rate=1,            # Normalization rate
    create_target_vector=True
)

window_size = 10

id_counter = Counter()
windows_count = 0
passage_count = 0

for passage in tqdm(dataset['train'], desc="Processing Passages"):
    passage_count += 1

    text = passage['text']
    preprocessed_text = encoder.preprocess(text, remove_stopwords=True)

    words_arr = np.array(preprocessed_text)
    words_arr = words_arr[:len(words_arr) - len(words_arr) % window_size]
    train_data = words_arr.reshape(-1, window_size)

    for window in train_data:
        tokenized_window = encoder.tokenize(window.tolist())
        one_hot = encoder.one_hot(tokenized_window, create_target_vector=True)
        model.update(one_hot)
        windows_count += 1
        id_counter.update(tokenized_window)

    # Save the model every 80,000 (1% of dataset)
    if passage_count % 80000 == 0:
        pct = passage_count // 80000
        utils.save_model(model, f"trained_models/original_openwebtext_checkpoints/model_checkpoint_{pct}pct.pt")
# Out:
# Processing Passages:   5%|▌         | 408220/8013769 [44:16<13:44:48, 153.68it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 39
#      37 tokenized_window = encoder.tokenize(window.tolist())
#      38 one_hot = encoder.one_hot(tokenized_window, create_target_vector=True)
# ---> 39 model.update(one_hot)
#      40 windows_count += 1
#      41 id_counter.update(tokenized_window)
#
# File ~/PycharmProjects/flyvec_extensions/flyvec_model.py:25, in FlyvecModel.update(self, x)
#      23 def update(self, x):
#      24     # Find indices of words in input (onehot vocab)
# ---> 25     active_indices = x.nonzero().squeeze(1)
#      27     # Calculate top k activations
#      28     activations = torch.sum(self.W[:, active_indices], dim=1)
#
# KeyboardInterrupt:

# %%
word_counter = {word: id_counter.get(id, 0) for word, id in vocab.items()}
word_counter = dict(sorted(word_counter.items(), key=lambda x: x[1], reverse=True))
word_counter
# Out:
# {'<UNK>': 38155221,
#  '<NUM>': 8305884,
#  'new': 612615,
#  'like': 596510,
#  'people': 584814,
#  'time': 567202,
#  'first': 473229,
#  'year': 422146,
#  'years': 346766,
#  'may': 314285,
#  'way': 307553,
#  'well': 304598,
#  'last': 304433,
#  'back': 302307,
#  'world': 296989,
#  'see': 289925,
#  'state': 284012,
#  'know': 261798,
#  'work': 258707,
#  'made': 258177,
#  'game': 257141,
#  'think': 254245,
#  'still': 248900,
#  'right': 247901,
#  'going': 247409,
#  'government': 236486,
#  'day': 234180,
#  'take': 230045,
#  'says': 227783,
#  'want': 226943,
#  'team': 209455,
#  'say': 208699,
#  'long': 207710,
#  'trump': 205410,
#  'need': 204438,
#  'part': 199503,
#  'president': 190425,
#  'city': 188521,
#  'life': 187150,
#  'told': 180098,
#  'high': 179943,
#  'public': 179528,
#  'police': 175530,
#  'end': 175080,
#  'best': 170617,
#  'next': 170271,
#  'old': 164880,
#  'system': 164616,
#  'found': 161412,
#  'states': 159463,
#  'great': 159280,
#  'according': 157966,
#  'man': 157629,
#  'come': 157524,
#  'including': 156748,
#  'called': 155835,
#  'home': 154673,
#  'group': 154023,
#  'little': 150558,
#  'help': 150275,
#  'point': 150249,
#  'show': 150224,
#  'look': 149932,
#  'season': 149812,
#  'set': 149296,
#  'number': 149037,
#  'million': 148321,
#  'week': 147764,
#  'second': 147534,
#  'support': 147016,
#  'place': 146400,
#  'news': 145343,
#  'using': 144671,
#  'american': 144565,
#  'country': 144266,
#  'times': 143872,
#  'case': 143595,
#  'women': 143504,
#  'big': 143405,
#  'left': 142909,
#  'national': 142544,
#  'data': 142382,
#  'house': 142151,
#  'play': 139976,
#  'find': 139598,
#  'power': 138877,
#  'based': 137828,
#  'company': 136736,
#  'top': 135090,
#  'free': 133659,
#  'law': 133603,
#  'put': 132351,
#  'change': 131631,
#  'percent': 131075,
#  'party': 130883,
#  'later': 130125,
#  'united': 129372,
#  'today': 128192,
#  'money': 127876,
#  'far': 127730,
#  'let': 125322,
#  'story': 125258,
#  'white': 124181,
#  'family': 123698,
#  'school': 123619,
#  'making': 123396,
#  'war': 122820,
#  'able': 118116,
#  'away': 117726,
#  'days': 117564,
#  'media': 117124,
#  'real': 116022,
#  'political': 115134,
#  'health': 114245,
#  'games': 114138,
#  'working': 114094,
#  'least': 113031,
#  'com': 112304,
#  'mr': 111913,
#  'came': 111461,
#  'run': 111391,
#  'court': 111335,
#  'full': 111137,
#  'name': 110151,
#  'actually': 110113,
#  'men': 109510,
#  'important': 109306,
#  'report': 108544,
#  'keep': 107998,
#  'order': 107896,
#  'start': 107862,
#  'open': 107596,
#  'early': 107465,
#  'took': 107221,
#  'university': 107188,
#  'give': 106121,
#  'small': 105956,
#  'post': 105923,
#  'past': 105498,
#  'children': 105278,
#  'business': 104919,
#  'line': 104459,
#  'level': 104263,
#  'security': 104108,
#  'players': 103991,
#  'social': 103953,
#  'human': 102399,
#  'known': 101398,
#  'community': 101326,
#  'given': 101125,
#  'video': 99974,
#  'read': 99529,
#  'campaign': 99111,
#  'seen': 98943,
#  'black': 98528,
#  'obama': 98523,
#  'example': 98327,
#  'hard': 97889,
#  'water': 97620,
#  'future': 97320,
#  'went': 97202,
#  'general': 96748,
#  'likely': 96578,
#  'control': 95930,
#  'feel': 95378,
#  'local': 95321,
#  'night': 95311,
#  'series': 95028,
#  'history': 94952,
#  'side': 94871,
#  'sure': 94810,
#  'following': 94725,
#  'person': 94477,
#  'asked': 94372,
#  'york': 94321,
#  'months': 94061,
#  'course': 93313,
#  'members': 93092,
#  'process': 93000,
#  'head': 92556,
#  'large': 92523,
#  'possible': 92482,
#  'across': 92251,
#  'means': 92243,
#  'love': 91898,
#  'month': 91281,
#  'office': 91058,
#  'research': 91003,
#  'young': 90609,
#  'kind': 90471,
#  'looking': 89822,
#  'service': 89660,
#  'project': 89285,
#  'believe': 89205,
#  'north': 89040,
#  'thought': 88963,
#  'book': 88284,
#  'makes': 88024,
#  'problem': 87854,
#  'call': 87797,
#  'live': 87278,
#  'area': 86914,
#  'major': 86863,
#  'market': 86738,
#  'federal': 86074,
#  'rights': 84811,
#  'half': 84460,
#  'issue': 84331,
#  'recent': 84315,
#  'america': 84247,
#  'started': 84242,
#  'added': 84226,
#  'bill': 83518,
#  'international': 83426,
#  'policy': 83172,
#  'ago': 82999,
#  'care': 82930,
#  'trying': 82798,
#  'idea': 82445,
#  'department': 81951,
#  'comes': 81884,
#  'experience': 81881,
#  'military': 81821,
#  'deal': 81764,
#  'player': 81340,
#  'south': 81310,
#  'move': 81074,
#  'john': 80218,
#  'class': 80075,
#  'program': 80023,
#  'space': 79947,
#  'study': 79635,
#  'try': 79604,
#  'job': 79451,
#  'clear': 79427,
#  'question': 79200,
#  'current': 79102,
#  'death': 78733,
#  'saying': 78724,
#  'third': 78517,
#  'face': 78300,
#  'single': 78073,
#  'bit': 78044,
#  'taken': 77906,
#  'center': 77718,
#  'energy': 77685,
#  'list': 77662,
#  'taking': 77444,
#  'food': 77365,
#  'image': 77249,
#  'film': 76646,
#  'pay': 76570,
#  'action': 76530,
#  'close': 75890,
#  'body': 75474,
#  'plan': 75447,
#  'wanted': 75347,
#  'coming': 75286,
#  'hand': 75198,
#  'al': 75085,
#  'development': 75039,
#  'low': 74253,
#  'tax': 74168,
#  'true': 74025,
#  'non': 73950,
#  'clinton': 73881,
#  'washington': 73716,
#  'act': 73542,
#  'create': 73084,
#  'due': 72795,
#  'points': 72752,
#  'form': 72701,
#  'league': 72633,
#  'air': 72631,
#  'reported': 72111,
#  'continue': 71968,
#  'de': 71835,
#  'win': 71734,
#  'bad': 71719,
#  'building': 71474,
#  'final': 70688,
#  'force': 70572,
#  'students': 70315,
#  'officials': 70267,
#  'tell': 70124,
#  'attack': 70000,
#  'issues': 69937,
#  'similar': 69933,
#  'result': 69896,
#  'decision': 69811,
#  'self': 69716,
#  'whole': 69694,
#  'companies': 69662,
#  'wrote': 69527,
#  'access': 69255,
#  'matter': 69217,
#  'services': 68916,
#  'hours': 68857,
#  'released': 68857,
#  'release': 68775,
#  'car': 68629,
#  'reason': 68599,
#  'twitter': 68581,
#  'running': 68461,
#  'election': 68428,
#  'china': 68348,
#  'street': 68261,
#  'special': 68214,
#  'view': 68060,
#  'short': 67759,
#  'press': 67706,
#  'director': 67554,
#  'woman': 67395,
#  'role': 67381,
#  'key': 67321,
#  'return': 67304,
#  'statement': 67295,
#  'front': 67102,
#  'especially': 67068,
#  'music': 66926,
#  'light': 66891,
#  'simply': 66782,
#  'began': 66729,
#  'cost': 66632,
#  'economic': 66581,
#  'age': 66575,
#  'evidence': 66463,
#  'version': 66114,
#  'lead': 66031,
#  'talk': 65924,
#  'value': 65886,
#  'term': 65836,
#  'west': 65829,
#  'mean': 65396,
#  'record': 65307,
#  'hit': 65293,
#  'red': 65261,
#  'lost': 65137,
#  'source': 65105,
#  'countries': 64993,
#  'online': 64815,
#  'turn': 64801,
#  'code': 64724,
#  'led': 64723,
#  'industry': 64674,
#  'late': 64459,
#  'earlier': 64347,
#  'event': 64277,
#  'groups': 64259,
#  'march': 64230,
#  'share': 64200,
#  'playing': 64176,
#  'pretty': 64064,
#  'needed': 63957,
#  'technology': 63828,
#  'include': 63726,
#  'recently': 63579,
#  'near': 63441,
#  'shows': 63339,
#  'article': 63152,
#  'site': 63146,
#  'star': 63017,
#  'needs': 63008,
#  'type': 62838,
#  'room': 62777,
#  'minister': 62512,
#  'position': 62190,
#  'strong': 62173,
#  'saw': 62132,
#  'test': 61743,
#  'played': 61715,
#  'changes': 61595,
#  'sense': 61582,
#  'vote': 61232,
#  'field': 60941,
#  'google': 60889,
#  'friends': 60866,
#  'total': 60758,
#  'photo': 60476,
#  'anti': 60351,
#  'mind': 59918,
#  'watch': 59781,
#  'forward': 59755,
#  'held': 59528,
#  'build': 59491,
#  'results': 59482,
#  'price': 59465,
#  'higher': 59357,
#  'fight': 59333,
#  'global': 59283,
#  'fire': 59198,
#  'facebook': 59120,
#  'weeks': 59099,
#  'longer': 58993,
#  'official': 58581,
#  'words': 58270,
#  'republican': 58208,
#  'science': 58139,
#  'june': 58054,
#  'common': 58034,
#  'private': 57878,
#  'rate': 57866,
#  'potential': 57781,
#  'network': 57589,
#  'soon': 57362,
#  'god': 57280,
#  'administration': 57224,
#  'foreign': 57111,
#  'inside': 57087,
#  'nearly': 57073,
#  'created': 57047,
#  'page': 56896,
#  'hope': 56781,
#  'billion': 56775,
#  'understand': 56768,
#  'minutes': 56601,
#  'design': 56525,
#  'original': 56448,
#  'average': 56427,
#  'financial': 56396,
#  'middle': 56347,
#  'july': 56211,
#  'add': 56146,
#  'bring': 56085,
#  'workers': 55905,
#  'legal': 55840,
#  'living': 55836,
#  'child': 55788,
#  'problems': 55637,
#  'internet': 55481,
#  'received': 55429,
#  'works': 55348,
#  'yes': 55332,
#  'easy': 55332,
#  'interest': 55124,
#  'increase': 55104,
#  'member': 55101,
#  'board': 55055,
#  'currently': 55007,
#  'ways': 54974,
#  'maybe': 54921,
#  'email': 54919,
#  'americans': 54825,
#  'content': 54766,
#  'questions': 54760,
#  'model': 54709,
#  'leave': 54529,
#  'expected': 54522,
#  'shot': 54472,
#  'reports': 54463,
#  'users': 54451,
#  'chief': 54353,
#  'trade': 54086,
#  'college': 53984,
#  'april': 53980,
#  'phone': 53785,
#  'friday': 53780,
#  'personal': 53775,
#  'announced': 53687,
#  'response': 53555,
#  'involved': 53499,
#  'russia': 53421,
#  'society': 53275,
#  'risk': 53250,
#  'allow': 53061,
#  'follow': 52985,
#  'medical': 52837,
#  'fans': 52836,
#  'finally': 52812,
#  'step': 52793,
#  'published': 52774,
#  'defense': 52702,
#  'killed': 52493,
#  'effect': 52442,
#  'performance': 52227,
#  'wrong': 52085,
#  'county': 52061,
#  'land': 52060,
#  'club': 52016,
#  'cases': 52014,
#  'cut': 51984,
#  'east': 51851,
#  'nation': 51764,
#  'worked': 51677,
#  'note': 51538,
#  'lives': 51413,
#  'monday': 51402,
#  'justice': 51364,
#  'terms': 51306,
#  'amount': 51293,
#  'oil': 51243,
#  'ability': 51103,
#  'race': 51012,
#  'david': 51002,
#  'road': 50885,
#  'committee': 50840,
#  'takes': 50762,
#  'goal': 50736,
#  'sign': 50664,
#  'difficult': 50497,
#  'park': 50497,
#  'tuesday': 50484,
#  'leader': 50454,
#  'period': 50388,
#  'ground': 50354,
#  'simple': 50192,
#  'rest': 50174,
#  'gave': 50126,
#  'entire': 50108,
#  'meeting': 50106,
#  'staff': 50005,
#  'january': 49989,
#  'moment': 49899,
#  'check': 49655,
#  'happened': 49569,
#  'september': 49561,
#  'bank': 49549,
#  'central': 49540,
#  'tv': 49463,
#  'production': 49401,
#  'size': 49396,
#  'events': 49359,
#  'teams': 49358,
#  'education': 49355,
#  'turned': 49343,
#  'sex': 49334,
#  'forces': 49314,
#  'character': 49267,
#  'chance': 49183,
#  'morning': 49131,
#  'november': 49129,
#  'plans': 49078,
#  'built': 48949,
#  'goes': 48945,
#  'union': 48917,
#  'father': 48839,
#  'career': 48780,
#  'european': 48685,
#  'israel': 48671,
#  'democratic': 48659,
#  'images': 48626,
#  'agency': 48534,
#  'situation': 48294,
#  'movement': 48151,
#  'canada': 48141,
#  'decided': 48065,
#  'uk': 48023,
#  'website': 47975,
#  'ask': 47962,
#  'significant': 47896,
#  'felt': 47875,
#  'cause': 47853,
#  'areas': 47837,
#  'green': 47724,
#  'word': 47701,
#  'economy': 47676,
#  'couple': 47630,
#  'training': 47589,
#  'congress': 47510,
#  'popular': 47501,
#  'buy': 47458,
#  'russian': 47446,
#  'http': 47335,
#  'growth': 47289,
#  'numbers': 47274,
#  'october': 47224,
#  'language': 47118,
#  'paul': 47040,
#  'thursday': 47028,
#  'previous': 46956,
#  'focus': 46921,
#  'british': 46819,
#  'quickly': 46764,
#  'wednesday': 46695,
#  'heard': 46660,
#  'lower': 46660,
#  'spent': 46647,
#  'mother': 46637,
#  'account': 46335,
#  'huge': 46307,
#  'sunday': 46262,
#  'range': 46253,
#  'climate': 46253,
#  'church': 46160,
#  'included': 45969,
#  'rules': 45923,
#  'population': 45889,
#  'figure': 45866,
#  'systems': 45828,
#  'art': 45798,
#  'knew': 45705,
#  'wants': 45647,
#  'tried': 45488,
#  'california': 45292,
#  'december': 45267,
#  'user': 45262,
#  'europe': 45243,
#  'hold': 45243,
#  'looks': 45228,
#  'san': 45226,
#  'august': 45098,
#  'quality': 45041,
#  'interview': 45020,
#  'attention': 44930,
#  'offer': 44902,
#  'impact': 44843,
#  'allowed': 44778,
#  'happen': 44718,
#  'council': 44699,
#  'present': 44645,
#  'jobs': 44628,
#  'written': 44617,
#  'features': 44586,
#  'earth': 44541,
#  'talking': 44495,
#  'town': 44477,
#  'dead': 44398,
#  'mark': 44355,
#  'century': 44170,
#  'brought': 44164,
#  'investigation': 44149,
#  'conference': 44111,
#  'base': 44089,
#  'address': 44049,
#  'learn': 43893,
#  'round': 43884,
#  'senate': 43764,
#  'majority': 43755,
#  'summer': 43699,
#  'individual': 43645,
#  'natural': 43512,
#  'guy': 43510,
#  'india': 43510,
#  'worth': 43467,
#  'specific': 43400,
#  'leaders': 43375,
#  'officers': 43290,
#  'latest': 43231,
#  'parents': 43213,
#  'football': 43183,
#  'drug': 43109,
#  'hands': 43105,
#  'fall': 43021,
#  'app': 42922,
#  'donald': 42856,
#  'officer': 42775,
#  'date': 42765,
#  'considered': 42745,
#  'violence': 42729,
#  'daily': 42706,
#  'stay': 42608,
#  'remember': 42564,
#  'advertisement': 42562,
#  'starting': 42521,
#  'file': 42515,
#  'review': 42502,
#  'store': 42345,
#  'success': 42235,
#  'approach': 42156,
#  'son': 42116,
#  'dr': 42086,
#  'complete': 42054,
#  'gun': 42047,
#  'army': 42035,
#  'message': 41981,
#  'product': 41877,
#  'movie': 41840,
#  'heart': 41789,
#  'modern': 41780,
#  'levels': 41770,
#  'writing': 41752,
#  'certainly': 41744,
#  'paid': 41613,
#  'reading': 41445,
#  'details': 41437,
#  'continued': 41426,
#  'style': 41416,
#  'standard': 41396,
#  'pass': 41347,
#  'stories': 41310,
#  'wall': 41225,
#  'executive': 41206,
#  'completely': 41201,
#  'income': 41199,
#  'attacks': 41198,
#  'saturday': 41194,
#  'growing': 41159,
#  'addition': 41155,
#  'answer': 41141,
#  'safety': 41138,
#  'london': 41110,
#  'claims': 41028,
#  'leading': 41000,
#  'intelligence': 40990,
#  'michael': 40975,
#  'products': 40946,
#  'software': 40918,
#  'opportunity': 40913,
#  'biggest': 40807,
#  'nature': 40771,
#  'sound': 40749,
#  'exactly': 40705,
#  'culture': 40669,
#  'student': 40634,
#  'required': 40612,
#  'damage': 40607,
#  'practice': 40598,
#  'february': 40528,
#  'friend': 40485,
#  'kids': 40431,
#  'paper': 40404,
#  'multiple': 40392,
#  'st': 40323,
#  'additional': 40248,
#  'district': 40246,
#  'stand': 40227,
#  'ready': 40204,
#  'king': 40167,
#  'named': 40114,
#  'region': 40103,
#  'function': 40039,
#  'title': 40027,
#  'interesting': 40018,
#  'giving': 39981,
#  'thinking': 39979,
#  'drive': 39958,
#  'apple': 39907,
#  'prime': 39852,
#  'james': 39845,
#  'choice': 39840,
#  'stage': 39809,
#  'organization': 39781,
#  'consider': 39656,
#  'changed': 39646,
#  'write': 39638,
#  'coach': 39583,
#  'deep': 39559,
#  'republicans': 39503,
#  'break': 39397,
#  'expect': 39379,
#  'pick': 39369,
#  'effort': 39227,
#  'effects': 39214,
#  'reality': 39174,
#  'looked': 39062,
#  'match': 39061,
#  'blue': 39039,
#  'speed': 39036,
#  'laws': 39017,
#  'credit': 38980,
#  'cover': 38885,
#  'web': 38847,
#  'eventually': 38830,
#  'capital': 38829,
#  'costs': 38823,
#  'fun': 38768,
#  'meet': 38748,
#  'parts': 38737,
#  'increased': 38720,
#  'relationship': 38718,
#  'sexual': 38691,
#  'search': 38444,
#  'computer': 38413,
#  'ball': 38386,
#  'card': 38380,
#  'designed': 38339,
#  'showed': 38327,
#  'sort': 38305,
#  'happy': 38285,
#  'chinese': 38260,
#  'wife': 38241,
#  'western': 38204,
#  'books': 38135,
#  'analysis': 38112,
#  'calls': 38093,
#  'remains': 38089,
#  'hour': 38011,
#  'voters': 37898,
#  'died': 37850,
#  'thousands': 37828,
#  'texas': 37808,
#  'alone': 37768,
#  'civil': 37754,
#  'guys': 37730,
#  'amp': 37595,
#  'nuclear': 37501,
#  'lack': 37474,
#  'includes': 37405,
#  'fast': 37369,
#  'comments': 37353,
#  'efforts': 37317,
#  'judge': 37243,
#  'claim': 37242,
#  'la': 37234,
#  'moving': 37230,
#  'senior': 37219,
#  'met': 37190,
#  'speech': 37155,
#  'hear': 37121,
#  'limited': 37113,
#  'budget': 37108,
#  'loss': 37022,
#  'scene': 37001,
#  'studies': 36988,
#  'ones': 36966,
#  'politics': 36951,
#  'directly': 36933,
#  'presidential': 36861,
#  'environment': 36856,
#  'property': 36841,
#  'pressure': 36840,
#  'target': 36793,
#  'religious': 36743,
#  'update': 36730,
#  'battle': 36716,
#  'stuff': 36697,
#  'secretary': 36662,
#  'gas': 36657,
#  'track': 36561,
#  'letter': 36540,
#  'super': 36475,
#  'crime': 36467,
#  'freedom': 36449,
#  'piece': 36379,
#  'ahead': 36226,
#  'schools': 36148,
#  'dark': 36118,
#  'beginning': 36019,
#  'manager': 36007,
#  'democrats': 35996,
#  'debate': 35956,
#  'remain': 35847,
#  'table': 35714,
#  'device': 35671,
#  'compared': 35634,
#  'subject': 35617,
#  'moved': 35530,
#  'thanks': 35446,
#  'largest': 35435,
#  'poor': 35399,
#  'passed': 35372,
#  'comment': 35370,
#  'save': 35325,
#  'brain': 35320,
#  'contact': 35298,
#  'box': 35267,
#  'conditions': 35168,
#  'visit': 35152,
#  'receive': 35150,
#  'text': 35135,
#  'blood': 35063,
#  'conservative': 35039,
#  'reasons': 34947,
#  'associated': 34940,
#  'born': 34857,
#  'characters': 34814,
#  'clearly': 34780,
#  'reach': 34746,
#  'failed': 34708,
#  'challenge': 34585,
#  'french': 34493,
#  'safe': 34470,
#  'helped': 34460,
#  'spending': 34458,
#  'eyes': 34458,
#  'independent': 34432,
#  'crisis': 34431,
#  'candidate': 34427,
#  'screen': 34375,
#  'english': 34354,
#  'wide': 34297,
#  'families': 34262,
#  'core': 34243,
#  'voice': 34242,
#  'powerful': 34224,
#  'hospital': 34204,
#  'mass': 34177,
#  'difference': 34117,
#  'sports': 34116,
#  'treatment': 34092,
#  'researchers': 34073,
#  'digital': 34066,
#  'cup': 34020,
#  'windows': 34014,
#  'bitcoin': 33947,
#  'physical': 33857,
#  'resources': 33827,
#  'actions': 33814,
#  'greater': 33792,
#  'shown': 33790,
#  'rule': 33778,
#  'section': 33729,
#  'previously': 33720,
#  'signed': 33694,
#  'feature': 33661,
#  'protect': 33658,
#  'charge': 33581,
#  'management': 33560,
#  'threat': 33524,
#  'author': 33437,
#  'george': 33432,
#  'syria': 33431,
#  'weapons': 33381,
#  'german': 33327,
#  'status': 33312,
#  'fear': 33262,
#  'ice': 33241,
#  'forced': 33229,
#  'records': 33207,
#  'germany': 33203,
#  'brown': 33201,
#  'sources': 33181,
#  'australia': 33140,
#  'fighting': 32947,
#  'allows': 32934,
#  'block': 32806,
#  'rise': 32799,
#  'followed': 32781,
#  'projects': 32771,
#  'developed': 32752,
#  'benefits': 32686,
#  'sea': 32639,
#  'girl': 32631,
#  'basic': 32605,
#  'ideas': 32588,
#  'positive': 32565,
#  'easily': 32551,
#  'customers': 32527,
#  'picture': 32512,
#  'primary': 32492,
#  'uses': 32440,
#  'attorney': 32438,
#  'attempt': 32406,
#  'option': 32384,
#  'begin': 32373,
#  'fully': 32346,
#  'gives': 32320,
#  'association': 32282,
#  'posted': 32281,
#  'female': 32248,
#  'eu': 32228,
#  'mobile': 32216,
#  'decades': 32208,
#  'individuals': 32161,
#  'cities': 32125,
#  'criminal': 32108,
#  'plus': 32085,
#  'speaking': 32058,
#  'contract': 32012,
#  'photos': 32011,
#  'authorities': 31981,
#  'agreement': 31963,
#  'station': 31931,
#  'shooting': 31896,
#  'fine': 31880,
#  'highly': 31866,
#  'gold': 31749,
#  'perfect': 31749,
#  'link': 31743,
#  'truth': 31739,
#  'larger': 31717,
#  'reached': 31717,
#  'calling': 31709,
#  'adding': 31708,
#  'lines': 31673,
#  'professor': 31665,
#  'door': 31649,
#  'goals': 31622,
#  'smith': 31620,
#  'rates': 31545,
#  'options': 31530,
#  'avoid': 31419,
#  'noted': 31393,
#  'hillary': 31378,
#  'island': 31376,
#  'winning': 31301,
#  'continues': 31300,
#  'sales': 31240,
#  'material': 31185,
#  'nice': 31159,
#  'programs': 31141,
#  'commission': 31113,
#  'citizens': 31104,
#  'successful': 31083,
#  'pre': 31025,
#  'scale': 31022,
#  'activity': 31009,
#  'band': 30988,
#  'regular': 30961,
#  'color': 30925,
#  'creating': 30922,
#  'secret': 30873,
#  'direct': 30860,
#  'traditional': 30854,
#  'feet': 30843,
#  'iran': 30838,
#  'cent': 30826,
#  'unique': 30814,
#  'knowledge': 30800,
#  'places': 30770,
#  ...}

# %%
# Find words with embeddings most similar to the target word embedding
target_word = 'bird'
hash_length = 40
top_N_closest = 20

#model = utils.load_model('trained_models/.pt')
import utils

utils.calc_print_sim_words(
    vocab=vocab,
    word_counts=word_counter,
    model=model,
    word=target_word,
    hash_len=hash_length,
    top_N=top_N_closest,
    create_target_vector=True
)
# Out:
# Word            Similarity Frequency
# -----------------------------------
# bird                1.000       9728
# adversity           0.885        993
# threeday            0.885          1
# citizens            0.880      31104
# here’s              0.880          0
# shop                0.880      17188
# jake                0.880       5190
# rewards             0.880       6772
# est                 0.880       4538
# urls                0.880       1261
# group’s             0.875          0
# responsibility      0.875      19924
# tournament          0.875      17125
# drawing             0.875      11858
# admitting           0.875       2856
# gaining             0.875       5233
# out”                0.875          0
# iso                 0.875       2720
# sizeable            0.875        819
# biblical            0.875       3602
